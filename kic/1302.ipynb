# %%
ric = 'kic'
table_name = 'normal_log_webos60'
model_type = '27ART10'

df1 = spark.sql(f'''
with dim_cc as (
  select country_code
  from   {ric}_data_dimension.common.country_code
  where  lower(region) = '{ric}'
), filter_raw as (
  SELECT
      X_device_platform as `platform_code`,  -- 필수 열
      X_device_product as `platform_version`,-- 필수 열
      X_Device_Country as `country_code`,    -- 필수/조건 열
      log_create_time,                       -- 필수/조건 열
      X_Device_SDK_VERSION as `dpv`,
      mac_addr,               -- 필수 열  
      x_device_sales_model as `model_name`, -- 필수 열
      context_name,                          -- 필수/조건 열  
      message_id,                            -- 필수/조건 열
      normal_log:Policy
  FROM {ric}_data_ods.tlamp.{table_name}
  WHERE 1=1
      AND context_name = 'tvbatteryd'
      AND message_id = 'NL_BATTERY_STATE'
      AND date_ym >= '2025-01'
      AND date_ym < '2026-03'
      AND x_device_sales_model LIKE '{model_type}%' -- 스탠바이미
      AND normal_log:Policy is not null        -- NULL 제외 
)

select mac_addr, Policy, model_name, count(1) as access_count
from   filter_raw nl
LEFT JOIN dim_cc cc on nl.country_code = cc.country_code
group by mac_addr, Policy, model_name
order by count(1) desc
''')

df1.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save(f's3://s3-lge-he-inbound-{ric}-dev/HEDS/1302/{ric}_{model_type}')

# %%
ric = 'kic'
table_name = 'normal_log_webos22'
model_type = '27LX5'

df2 = spark.sql(f'''
with dim_cc as (
  select country_code
  from   {ric}_data_dimension.common.country_code
  where  lower(region) = '{ric}'
), filter_raw as (
  SELECT
      X_device_platform as `platform_code`,  -- 필수 열
      X_device_product as `platform_version`,-- 필수 열
      X_Device_Country as `country_code`,    -- 필수/조건 열
      log_create_time,                       -- 필수/조건 열
      X_Device_SDK_VERSION as `dpv`,
      mac_addr,               -- 필수 열  
      x_device_sales_model as `model_name`, -- 필수 열
      context_name,                          -- 필수/조건 열  
      message_id,                            -- 필수/조건 열
      normal_log:Policy
  FROM {ric}_data_ods.tlamp.{table_name}
  WHERE 1=1
      AND context_name = 'tvbatteryd'
      AND message_id = 'NL_BATTERY_STATE'
      AND date_ym >= '2025-01'
      AND date_ym < '2026-03'
      AND x_device_sales_model LIKE '{model_type}%' -- 스탠바이미
      AND normal_log:Policy is not null        -- NULL 제외 
)

select mac_addr, Policy, model_name, count(1) as access_count
from   filter_raw nl
LEFT JOIN dim_cc cc on nl.country_code = cc.country_code
group by mac_addr, Policy, model_name
order by count(1) desc
''')

df2.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save(f's3://s3-lge-he-inbound-{ric}-dev/HEDS/1302/{ric}_{model_type}')

# %%
ric = 'kic'
table_name = 'normal_log_webos24'
model_type = '27LX6T'

df3 = spark.sql(f'''
with dim_cc as (
  select country_code
  from   {ric}_data_dimension.common.country_code
  where  lower(region) = '{ric}'
), filter_raw as (
  SELECT
      X_device_platform as `platform_code`,  -- 필수 열
      X_device_product as `platform_version`,-- 필수 열
      X_Device_Country as `country_code`,    -- 필수/조건 열
      log_create_time,                       -- 필수/조건 열
      X_Device_SDK_VERSION as `dpv`,
      mac_addr,               -- 필수 열  
      x_device_sales_model as `model_name`, -- 필수 열
      context_name,                          -- 필수/조건 열  
      message_id,                            -- 필수/조건 열
      normal_log:Policy
  FROM {ric}_data_ods.tlamp.{table_name}
  WHERE 1=1
      AND context_name = 'tvbatteryd'
      AND message_id = 'NL_BATTERY_STATE'
      AND date_ym >= '2025-01'
      AND date_ym < '2026-03'
      AND x_device_sales_model LIKE '{model_type}%' -- 스탠바이미
      AND normal_log:Policy is not null        -- NULL 제외 
)

select mac_addr, Policy, model_name, count(1) as access_count
from   filter_raw nl
LEFT JOIN dim_cc cc on nl.country_code = cc.country_code
group by mac_addr, Policy, model_name
order by count(1) desc
''')

df3.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save(f's3://s3-lge-he-inbound-{ric}-dev/HEDS/1302/{ric}_{model_type}')
