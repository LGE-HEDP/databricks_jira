# %%
# %sql
select count(1), count(distinct mac_addr_hashed)
from aic_data_private.tlamp.rbt_mac_addr_webos24
-- where

# %%
# %sql
select 
  count(1)
from sandbox.z_donghyun8_seo.sport_seg_2508_2510

# %%
# %sql
select 
  -- b.mac_addr, a.*
  count(1)
from sandbox.z_donghyun8_seo.sport_seg_2508_2510 a
left join aic_data_private.tlamp.rbt_mac_addr_webos24 b
 on a.mac_addr = b.mac_addr_hashed
where b.mac_addr is null

# %%
# %sql
select 
  b.mac_addr, a.*
  -- count(1)
from sandbox.z_donghyun8_seo.sport_seg_2508_2510 a
left join aic_data_private.tlamp.rbt_mac_addr_webos24 b
 on a.mac_addr = b.mac_addr_hashed
-- where b.mac_addr is null42466
