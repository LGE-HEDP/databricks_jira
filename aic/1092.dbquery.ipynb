-- %%
with pine24 as (
  SELECT 
      X_device_platform as `platform_code`,  -- 필수 열
      X_device_product as `platform_version`,-- 필수 열
      X_Device_Country as `country_code`,    -- 필수/조건 열
      log_create_time,                       -- 필수/조건 열
      -- X_Device_SDK_VERSION as `dpv`,
      mac_addr as `device_id`,               -- 필수 열  
      x_device_sales_model as `sales_model_code`, -- 필수 열
      -- context_name,                          -- 필수/조건 열  
      -- message_id,                            -- 필수/조건 열
      normal_log:bookmark as `bookmark`
  FROM aic_data_ods.tlamp.normal_log_webos22 a
  WHERE 1=1
      AND date_ym >= '2025-01' 
      and context_name = 'com.webos.app.homeoffice'
      and message_id = 'NL_USE_INTERNET_SERVICE'
      and get_json_object(normal_log, '$.banner_loaded') is null 
      and X_device_product = 'webOSTV 24'
      and exists (
          select distinct country_code
          from   aic_data_dimension.common.country_code
          where region = 'AIC'
            and a.X_Device_Country = country_code
      )
  
  union all 

  
  SELECT 
      X_device_platform as `platform_code`,  -- 필수 열
      X_device_product as `platform_version`,-- 필수 열
      X_Device_Country as `country_code`,    -- 필수/조건 열
      log_create_time,                       -- 필수/조건 열
      -- X_Device_SDK_VERSION as `dpv`,
      mac_addr as `device_id`,               -- 필수 열  
      x_device_sales_model as `sales_model_code`, -- 필수 열
      -- context_name,                          -- 필수/조건 열  
      -- message_id,                            -- 필수/조건 열
      normal_log:bookmark as `bookmark`
  FROM aic_data_ods.tlamp.normal_log_webos23 a
  WHERE 1=1
      AND date_ym >= '2025-01' 
      and context_name = 'com.webos.app.homeoffice'
      and message_id = 'NL_USE_INTERNET_SERVICE'
      and normal_log:banner_loaded is null 
      and X_device_product = 'webOSTV 24'
      and exists (
          select distinct country_code
          from   aic_data_dimension.common.country_code
          where region = 'AIC'
            and a.X_Device_Country = country_code
      )

  union all 
  
  SELECT 
      X_device_platform as `platform_code`,  -- 필수 열
      X_device_product as `platform_version`,-- 필수 열
      X_Device_Country as `country_code`,    -- 필수/조건 열
      log_create_time,                       -- 필수/조건 열
      -- X_Device_SDK_VERSION as `dpv`,
      mac_addr as `device_id`,               -- 필수 열  
      x_device_sales_model as `sales_model_code`, -- 필수 열
      -- context_name,                          -- 필수/조건 열  
      -- message_id,                            -- 필수/조건 열
      normal_log:bookmark as `bookmark`
  FROM aic_data_ods.tlamp.normal_log_webos24 a
  WHERE 1=1
      AND date_ym >= '2025-01' 
      and context_name = 'com.webos.app.homeoffice'
      and message_id = 'NL_USE_INTERNET_SERVICE'
      and normal_log:banner_loaded is null 
      and X_device_product = 'webOSTV 24'
      and exists (
          select distinct country_code
          from   aic_data_dimension.common.country_code
          where region = 'AIC'
            and a.X_Device_Country = country_code
      )

  union all 

  SELECT 
      X_device_platform as `platform_code`,  -- 필수 열
      X_device_product as `platform_version`,-- 필수 열
      X_Device_Country as `country_code`,    -- 필수/조건 열
      log_create_time,                       -- 필수/조건 열
      -- X_Device_SDK_VERSION as `dpv`,
      mac_addr as `device_id`,               -- 필수 열  
      x_device_sales_model as `sales_model_code`, -- 필수 열
      -- context_name,                          -- 필수/조건 열  
      -- message_id,                            -- 필수/조건 열
      normal_log:bookmark as `bookmark`
  FROM aic_data_ods.tlamp.normal_log_webos25 a
  WHERE 1=1
      AND date_ym >= '2025-01' 
      and context_name = 'com.webos.app.homeoffice'
      and message_id = 'NL_USE_INTERNET_SERVICE'
      and normal_log:banner_loaded is null 
      and X_device_product = 'webOSTV 24'
      and exists (
          select distinct country_code
          from   aic_data_dimension.common.country_code
          where region = 'AIC'
            and a.X_Device_Country = country_code
      )
)

select *
from   pine24 

union all 

SELECT 
    X_device_platform as `platform_code`,  -- 필수 열
    X_device_product as `platform_version`,-- 필수 열
    X_Device_Country as `country_code`,    -- 필수/조건 열
    log_create_time,                       -- 필수/조건 열
    -- X_Device_SDK_VERSION as `dpv`,
    mac_addr as `device_id`,               -- 필수 열  
    x_device_sales_model as `sales_model_code`, -- 필수 열
    -- context_name,                          -- 필수/조건 열  
    -- message_id,                            -- 필수/조건 열
    normal_log:bookmark as `bookmark`
FROM aic_data_ods.tlamp.normal_log_webos25 a
WHERE 1=1
    AND date_ym >= '2025-01' 
    and context_name = 'com.webos.app.homeoffice'
    and message_id = 'NL_USE_INTERNET_SERVICE'
    and normal_log:banner_loaded is null 
    and X_device_product = 'webOSTV 25'
    and exists (
        select distinct country_code
        from   aic_data_dimension.common.country_code
        where region = 'AIC'
        and a.X_Device_Country = country_code
    )
