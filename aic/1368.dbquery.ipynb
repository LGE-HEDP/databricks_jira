-- %%
-- select * from sandbox.t_scm.scm_miso_te_forecast;
-- select * from sandbox.t_scm.scm_miso_te_result;
-- select * from sandbox.t_scm.scm_miso_gt_forecast;
-- select * from sandbox.t_scm.scm_miso_gt_result;
-- select * from sandbox.t_scm.scm_miso_gfk_result_tv_lv1;
-- select * from sandbox.t_scm.scm_miso_gfk_result_tv_lv2;
-- select * from sandbox.t_scm.scm_miso_ml_final_models;
-- select * from sandbox.t_scm.scm_miso_ml_correlation;
-- select * from sandbox.t_scm.scm_miso_ml_determination_w_features;
-- select * from sandbox.t_scm.scm_miso_ml_importance_w_features;
-- select * from sandbox.t_scm.scm_miso_ml_final_forecast;
select * from sandbox.t_scm.scm_miso_ml_forecast;
