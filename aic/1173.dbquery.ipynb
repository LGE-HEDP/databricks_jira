-- %%
select table_nm, country_code, app_id, platform_version, case_label, UD, UD_user, UD_not_user, access, access_user, access_not_user, min_ymd, max_ymd, uniq_ymd_cnt, etl_dt
from sandbox.z_sam351_kim.a1211_apps_funnel_2_funnel_ud
order by table_nm, country_code, app_id, platform_version, case_label
