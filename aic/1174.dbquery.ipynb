-- %%
-- (query1) LG채널 MAU/CVR
select date_ym, country_code, platform_version, UD_app, UD_program, UD_program_livetv, UD_program_homeapp, UD_app_program, webOS_MAU, CVR_app, CVR_program, CVR_program_livetv, CVR_program_homeapp, CVR_app_program, CVR_netflix, CVR_youtube, CVR_tubi, CVR_cpapp
from sandbox.z_sam351_kim.a1215_lgch_task_1_lgch_cvr_mm 
order by date_ym, country_code, platform_version
;





-- (query2) 진입경로별 UD 비중 (lgcmp.app)
select date_ym, country, webosVersion, callerAppId, UD, access, UD_tot, UD_ratio, access_tot, access_ratio
from sandbox.z_sam351_kim.a1215_lgch_task_2_lgcmp_app_caller_mm 
order by date_ym, country, webosVersion, UD desc
;


-- (query3) 
select date_ym, country, webosVersion, callerAppId, UD, access_appSession, access_channelSession, access_ipChannelSession, UD_tot, UD_ratio, access_appSession_tot, access_channelSession_tot, access_ipChannelSession_tot, access_appSession_ratio, access_channelSession_ratio, access_ipChannelSession_ratio
from sandbox.z_sam351_kim.a1215_lgch_task_3_lgcmp_channel_caller_mm 
order by date_ym, country, webosVersion, UD desc
