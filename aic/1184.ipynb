# %% [markdown]
# http://jira.lge.com/issue/browse/HEDATAPLFM-1184?attachmentSortBy=dateTime&attachmentOrder=asc

# %%
# %sql
select * from sandbox.z_donghyun8_seo.w24_us_target_A

# %%
# %sql
select 
  count(A.mac_addr), count(distinct A.mac_addr), count(*)
from sandbox.z_donghyun8_seo.w24_us_target A

# %%
# %sql
select COUNT(*) 
  from sandbox.z_donghyun8_seo.w25_us_target_A

# %%
# %sql
select * from sandbox.z_donghyun8_seo.w25_us_target_A

# %%
# %sql
select
  B.mac_addr as mac_addr_origin, A.* 
from sandbox.z_donghyun8_seo.w24_us_target A
left join aic_data_private.tlamp.rbt_mac_addr_webos24 B
  on A.mac_addr = B.mac_addr_hashed

# %%
# %sql
select
  B.mac_addr as mac_addr_origin, A.* 
from sandbox.z_donghyun8_seo.w25_us_target A
left join aic_data_private.tlamp.rbt_mac_addr_webos25 B
  on A.mac_addr = B.mac_addr_hashed

# %%
# %sql
select 
  count(1), 
  count(distinct concat(mac_addr, mac_addr_hashed)), 
  count(distinct mac_addr), 
  count(distinct mac_addr_hashed)
from aic_data_private.tlamp.rbt_mac_addr_webos24
where 1=1
  -- and mac_addr_hashed ='0000037d43c1643612c9a2e3bd8e24b4a2bfb3a5458799bea4f4567f3e5ef829'

# %%
# %sql
select 
  -- count(A.mac_addr), count(distinct A.mac_addr)
  -- B.mac_addr as mac_addr_origin, A.* 
  distinct a.mac_addr
from sandbox.z_donghyun8_seo.w24_us_target A
left join aic_data_private.tlamp.rbt_mac_addr_webos24 B
  on A.mac_addr = B.mac_addr_hashed
where B.mac_addr is null

# %%
# %sql
select 
  -- count(A.mac_addr), count(distinct A.mac_addr)
  -- B.mac_addr as mac_addr_origin, A.* 
  distinct a.mac_addr
from sandbox.z_donghyun8_seo.w25_us_target A
left join aic_data_private.tlamp.rbt_mac_addr_webos25 B
  on A.mac_addr = B.mac_addr_hashed
where B.mac_addr is null

# %%
# %sql
select *
from aic_data_private.tlamp.rbt_mac_addr_webos25
where 1=1
  and mac_addr_hashed in ('ea786684d21355dda6e476e3eb27884e371317ad2938047a979ebf8bbf623f2c',
'91cac19c722a6a8335cee2f7376d124e2f5c531908796dbf16997fffd7fb685d',
'dc28f5066aa83a50af22f10a593f00b4425d7b2bfd3caca444b7f698b3e72a85',
'e7b2fe4d9d8ac8b9ae72cadf31b5ac2919bfa640964b43b9bf3c55ba63cd3682',
'7549eab75f9b5951b857bcfc05e6bc29c84f391f5872427730690feb33daca02',
'cf5f0df459e9f2f24b27e800e0fe7c9908fcfb93678845007a7b329071e0baa8',
'fddfe699f980de3432bf79b10ebbbdd3233a83b3589010b1a69d8442280d6823',
'03566c45ce77e4121bd754f5293bbd93f52faf9249410a06c4d53abdc1cfacd8',
'139b0e9c4c70cd1602c4fa07fc98eb9fc4885d1951aef8ee99bbc034dce60e20',
'73ae09453da6f4b96a0a7d458cc2bb018f30bbea95fea4a419c13cfd17dc15f3',
'4686a737edcae3eb85fcebe72ee825a6d6cfd7ca1c28144a1cfdc6e8533fb0ef')

# %%
# %sql
select *
from aic_data_private.tlamp.rbt_mac_addr_webos23
where 1=1
  and mac_addr_hashed in ('ea786684d21355dda6e476e3eb27884e371317ad2938047a979ebf8bbf623f2c',
